# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_json("generated_proj_data.json")
df
# Out:
#      Employee_id  Manager_id  Managed      Name  Phone_number    Job_role  \
# 0              1           1        2  Gennifer    6209593685   Frontware
# 1              2           2        3     James    9738020834    Hardware
# 2              3           3        4  Patricia    9355968186    Backware
# 3              4           4        5  Gennifer    5505514285   Frontware
# 4              5           5        6  Gennifer    2683833750  Middleware
# ..           ...         ...      ...       ...           ...         ...
# 995          996         996      997   Michael    2197356141    Software
# 996          997         997      998  Patricia    4853639191   Frontware
# 997          998         998      999   Michael    7164812715  Middleware
# 998          999         999     1000     James    1925391251   Frontware
# 999         1000        1000     1001     James    7139441816   Frontware
#
#     Work_location  Salary
# 0      North Pole  102658
# 1      South Pole   98392
# 2      North Pole  120111
# 3             WFH  106372
# 4             WFH   84623
# ..            ...     ...
# 995           WFH  104808
# 996       Toronto  116814
# 997    North Pole   87311
# 998    South Pole  116084
# 999    South Pole  104303
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Linear Regression modelling

# %%
df_dummy = df[['Job_role', 'Work_location']]
y = df['Salary'].astype(int)

X = pd.get_dummies(df_dummy, dtype=int)
X
# Out:
#      Job_role_Backware  Job_role_Frontware  Job_role_Hardware  \
# 0                    0                   1                  0
# 1                    0                   0                  1
# 2                    1                   0                  0
# 3                    0                   1                  0
# 4                    0                   0                  0
# ..                 ...                 ...                ...
# 995                  0                   0                  0
# 996                  0                   1                  0
# 997                  0                   0                  0
# 998                  0                   1                  0
# 999                  0                   1                  0
#
#      Job_role_Middleware  Job_role_Software  Work_location_North Pole  \
# 0                      0                  0                         1
# 1                      0                  0                         0
# 2                      0                  0                         1
# 3                      0                  0                         0
# 4                      1                  0                         0
# ..                   ...                ...                       ...
# 995                    0                  1                         0
# 996                    0                  0                         0
# 997                    1                  0                         1
# 998                    0                  0                         0
# 999                    0                  0                         0
#
#      Work_location_South Pole  Work_location_Toronto  Work_location_WFH
# 0                           0                      0                  0
# 1                           1                      0                  0
# 2                           0                      0                  0
# 3                           0                      0                  1
# 4                           0                      0                  1
# ..                        ...                    ...                ...
# 995                         0                      0                  1
# 996                         0                      1                  0
# 997                         0                      0                  0
# 998                         1                      0                  0
# 999                         1                      0                  0
#
# [1000 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2) 

model = LinearRegression()
model.fit(X_train, y_train) 

model.score(X_train, y_train)
# Out:
# 0.009274778086289626

# %%
model.score(X_test, y_test)
# Out:
# -0.015685699704533596

# %%
import pickle

# Specify the file path to save the pipeline
file_path = 'trained_model.pkl'

# Save the pipeline to disk
with open(file_path, 'wb') as file:
    pickle.dump(model, file)

# %%
import pickle 

load_model = pickle.load(open("trained_model.pkl", 'rb'))

# %%
import pandas as pd
import numpy as np
import pickle

# Load the encoders and model
model_loaded = pickle.load(open('trained_model.pkl', 'rb'))
#df = pd.read_csv('your_data.csv')  # Ensure you load your DataFrame

def predict_salary(job_role, work_location):     
    # Create a DataFrame for input
    df_input_data = pd.DataFrame({'job_role': [job_role], 'work_location': [work_location]})

    # One-hot encode the input data
    df_input_dummy = pd.get_dummies(df_input_data, columns=['job_role', 'work_location'], drop_first=True)

    # Ensure the input DataFrame matches the model's expected input
    df_input_dummy = df_input_dummy.reindex(columns=model_loaded.feature_names_in_, fill_value=0)

    # Make salary prediction
    model_prediction = model_loaded.predict(df_input_dummy)
    return model_prediction[0]

print("Enter your job role (e.g., Senior Software Engineer)")
job_role = input()
print("Enter your job location (e.g., Hartford, CT)")
work_location = input()

predicted_salary = predict_salary(job_role, work_location)
print(f'The salary for a {job_role} in {work_location} is predicted to be ${predicted_salary:.2f}')
# Out:
# Enter your job role (e.g., Senior Software Engineer)
# Enter your job location (e.g., Hartford, CT)
# The salary for a Backware in Toronto is predicted to be $927848435687387904.00
